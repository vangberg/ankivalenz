# %% [raw]
# ---
# description: Supporting types
# output-file: types.html
# title: Types
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Delimeters
#
# Strings like "::", "?::" and "::?" representing delimeters in notes

# %%
#|output: asis
#| echo: false
show_doc(Delimeter)
# Out:
# ---
#
# [source](https://github.com/vangberg/ankivalenz/blob/main/ankivalenz/types.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### Delimeter
#
# >      Delimeter (contents:str)

# %% [markdown]
# ## AST
#
# These types represent the nodes in the AST returned by `html_parser`

# %% [markdown]
# ## Cards
#
# These types represent the cards returned by `node_parser`

# %%
#|output: asis
#| echo: false
show_doc(ClozeCard)
# Out:
# ---
#
# [source](https://github.com/vangberg/ankivalenz/blob/main/ankivalenz/types.py#L33){target="_blank" style="float:right; font-size:smaller"}
#
# ### ClozeCard
#
# >      ClozeCard (question:str, path:list[str])

# %%
#|output: asis
#| echo: false
show_doc(BasicCard)
# Out:
# ---
#
# [source](https://github.com/vangberg/ankivalenz/blob/main/ankivalenz/types.py#L25){target="_blank" style="float:right; font-size:smaller"}
#
# ### BasicCard
#
# >      BasicCard (question:str, answer:str, path:list[str], reverse:bool=False)
