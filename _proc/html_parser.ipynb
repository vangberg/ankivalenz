# %% [raw]
# ---
# description: Parses HTML files into a structured format
# output-file: html_parser.html
# title: HTML Parser
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
