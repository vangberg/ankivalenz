# %% [raw]
# ---
# description: Fill in a module description here
# output-file: ankivalenz.html
# title: Ankivalenz
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#|output: asis
#| echo: false
show_doc(foo)
# Out:
# ---
#
# [source](https://github.com/vangberg/ankivalenz/blob/main/ankivalenz/core.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### foo
#
# >      foo ()

# %%
#|output: asis
#| echo: false
show_doc(say_hi)
# Out:
# ---
#
# [source](https://github.com/vangberg/ankivalenz/blob/main/ankivalenz/core.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### say_hi
#
# >      say_hi (to)
#
# Say hi to someone

# %%
assert say_hi("Harry") == "Hi Harry"
